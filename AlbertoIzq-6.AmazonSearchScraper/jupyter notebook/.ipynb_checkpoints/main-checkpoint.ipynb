# %%
import requests
from bs4 import BeautifulSoup

url = "https://www.amazon.es/s?k=guitarra+electrica&__mk_es_ES=%C3%85M%C3%85%C5%BD%C3%95%C3%91&ref=nb_sb_noss_2"
r = requests.get(url, headers={'User-agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:61.0) Gecko/20100101 Firefox/61.0'})
c = r.content
#c
soup = BeautifulSoup(c, "html.parser")
#print(soup.prettify())
all = soup.find_all("div", {"data-component-type": "s-search-result", "class": "s-result-item"})
#print(len(all))

counter = 1

for item in all:
    description = item.find_all("div", {"class": "a-section a-spacing-none a-spacing-top-small"})[0].find("span", {"class": "a-size-base-plus a-color-base a-text-normal"}).text
    #print("___", counter, ": ", description)
    
    try:
        stars = item.find("span", {"class": "a-icon-alt"}).text.replace(" de 5 estrellas", "")
    except:
        stars = None
    
    #print(stars, " stars")
    
    try:
        reviews = item.find_all("div", {"class": "a-section a-spacing-none a-spacing-top-micro"})[0].find("span", {"class": "a-size-base"}).text
    except:
        reviews = None
    
    #print(reviews, " reviews")
     
    try:
        price = item.find_all("div", {"class": "a-section a-spacing-none a-spacing-top-small"})[1].find("span", {"class": "a-price-whole"}).text
    except:
        price = None
    
    #print("price is ", price, " €")
    
    try:
        amazon_prime = item.find_all("div", {"class": "a-section a-spacing-none a-spacing-top-micro"})[1].find("i", {"class": "a-icon a-icon-prime a-icon-medium"})
        amazon_prime = "Yes"
        #print("AMAZON PRIME YES")
    except:
        amazon_prime = "No"
        #print("NO")
    
    try:
        best_seller = item.find("div", {"class": "a-section a-spacing-micro s-grid-status-badge-container"}).find_all("span", {"class": "a-badge-text"})[0]
        best_seller = "Yes"
        print("Más vendido")
    except:
        best_seller = "No"

    #counter = counter + 1

print("Counter is: ", counter)
'''
Description
Stars
Reviews
Price
'''
# Out:
# ___ 1 :  YAMAHA GuitarGo, Set para principiantes y para aquellos que quieran retomarlo, incluye cuerdas, púas, funda, diapasón, atril y mucho más
# ___ 1 :  Roadie 2 afinador de guitarra automático independiente
# ___ 1 :  Afinador de guitarra automático e independiente Roadie Bass
# ___ 1 :  PlutuX Soporte de Guitarra de Madera Soporte de Instrumento de Música Nogal Negro para Acústica, Eléctrica, Clásica
# ___ 1 :  RockJam Superkit Guitarra eléctrica de tamaño completo con amplificador de guitarra, Cuerdas de guitarra, Sintonizador, Correa, Estuche y cable, color Negro
# Más vendido
# ___ 2 :  RockJam Superkit de guitarra eléctrica de tamaño completo con amplificador de guitarra, Cuerdas de guitarra, Correa, Bolsa y cable de guitarra Sunburst
# ___ 2 :  ammoon 10W Amplificador de Guitarra Eléctrico Portatil, Sonido Analógico, Soporte de Conexión BT, Doble Fuente de Alimentación
# ___ 2 :  D'Addario EPS510 - Juego de cuerdas para guitarra eléctrica de acero, 010' - 046', transparente
# ___ 2 :  Display4top Kit de guitarra eléctrica Amplificador de 20 vatios, soporte de guitarra, bolsa, púa de guitarra, correa, cuerdas de repuesto, sintonizador, estuche y cable (Negro-Negro)
# ___ 2 :  AmazonBasics - Correa ajustable para guitarra eléctrica/acústica/bajo, incluye 2 púas, correa suave con extremos de piel sintética, negro
# ___ 7 :  Planet Waves 1CAP4-10 - Púas de caparazón de tortuga, tamaño media, paquete de 10
# Más vendido
# ___ 8 :  Ibanez IEGS6 - Juego cuerdas para guitarra eléctrica
# ___ 8 :  Cuerdas de guitarra eléctrica de cuerda de acero inoxidable Slinky Ernie Ball regular - 10-46 Gauge
# ___ 8 :  Rocktile 19331 - Pack guitarra eléctrica Banger 7 piezas, color negro
# ___ 8 :  Anpro Cejilla Guitarra,Capo Guitarra,Cejilla Guitarra Acustica,Clasica,Electrica,Española,Ukelele,Folk,Cejilla Negra con 6 Púas
# ___ 8 :  D'Addario EXL120-3D - Juego de cuerdas para guitarra eléctrica de acero y níquel, .009 - .042
# ___ 8 :  ammoon Amplificador de Guitarra Portátil POCKAMP Amplificador de 5 Vatios Multiefectos Incorporados 80 Ritmos de Batería Compatibilidad con el Sintonizador
# Más vendido
# ___ 9 :  D'Addario NYXL1046 - Juego de cuerdas para guitarra eléctrica, 10-46
# ___ 9 :  Neewer 6 Piezas Pomos de Cabezales de Guitarra de Guitarra Clavijas de Afinación de Guitarra Sintonizadores de Cabeza de Máquina para Guitarra Eléctrica o Acústica (3 para Izquierda + 3 para Derecha)
# ___ 9 :  Yamaha YTC5 - Afinador electrónico de tipo pinza, color negro
# ___ 9 :  3rd Avenue STX30RDPK - Paquete junior de guitarra eléctrica, Rojo
# Más vendido
# ___ 10 :  Ibanez GRGM21-BKN - Guitarra eléctrica
# ___ 10 :  D'Addario EXL110-3D - Juego de cuerdas para guitarra eléctrica de acero y níquel (pack 3 juegos)
# ___ 10 :  Anpro 26PCS Kit de Herramienta Guitarra,Accesorios Guitarra,Herramientas de Limpieza y Mantenimiento para Guitarra, Ukelele, Bajo, Mandolina, Banjo
# ___ 10 :  ammoon Kit Herramientas de Guitarra Mantenimiento de Reparación de Limpieza Incluye Organizador de Cuerdas y String Action Ruler&Calibre Herramienta de Medición&Juego de Llaves Hexagonales y Archivos
# ___ 10 :  Elixir 12002 - Juego de cuerdas para guitarra eléctrica, .009 - 0.042
# ___ 10 :  Ernie Ball EB4037 - Correas para guitarras
# Más vendido
# ___ 11 :  ammoon PG-3 Control de 3W guitarra eléctrica amperio amplificador del altavoz de tono del volumen
# ___ 11 :  Donner Verb Square 7- Pedal Efecto de Reverberación de Guitarra Con 7 Modos
# ___ 11 :  Fender Frontman - 10G Amplificador para guitarra, 230 V EUR
# ___ 11 :  Fender Squier Affinity Stratocaster LRL HSS Brown Sunburst + Frontman 15G + Funda Guitarra Eléctrica
# ___ 11 :  MARTISAN Soporte de guitarra Universal Plegable para Guitarra Eléctrica Guitarras Acustica Electrica Bajo
# ___ 11 :  RockJam Soporte de guitarra vertical universal para todas las guitarras, Soporte de guitarra clásica, acústica, eléctrica y baja
# ___ 11 :  Rocktile Scream-15 - Amplificador para guitarra
# Counter is:  11
# '\nDescription\nStars\nReviews\nPrice\n'

# %%
#dir(str)
